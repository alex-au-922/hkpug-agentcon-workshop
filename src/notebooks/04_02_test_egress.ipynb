# %% [markdown]
# # Stage 04.02: Test Egress
#
# The trainer should delete the shared `istio-system/workshop-open-egress` entry before this stage. Then apply `manifests/04_01_allow_agentcon_api.yaml` and rerun this notebook.

# %%
from workshop import test_egress

# %%
test_egress()
