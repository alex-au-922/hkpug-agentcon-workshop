# %% [markdown]
# # Stage 02.02: Secure Compute
#
# Apply `manifests/02_01_block_sa_token.yaml` first if the trainer asks you to demonstrate kernel enforcement before the sandbox step. Then run this notebook to observe the Web IDE staying alive while the sandbox blocks dangerous capability use.

# %%
from workshop import run_secure_compute_demo

# %%
result = run_secure_compute_demo()
result

# %% [markdown]
# If `result['error']` is set, the sandbox blocked the dangerous operation without crashing the host notebook session.
