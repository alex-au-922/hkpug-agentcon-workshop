# %% [markdown]
# # Stage 03.02: Internal DB AuthZ
#
# Run this once before applying `manifests/03_01_allow_internal_db.yaml` so you can observe the default deny. Then apply the manifest and rerun the notebook to confirm keyless access.

# %%
from workshop import query_internal_db

# %%
query_internal_db()
